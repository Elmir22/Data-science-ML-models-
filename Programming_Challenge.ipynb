# %% [markdown]
# <a href="https://colab.research.google.com/github/Elmir22/Data-science-ML-models-/blob/main/Programming_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/MO14-Round-1-Dealing-With-Data-Workbook.csv')

# %%
df
# Out:
#           3 PM  Mon 24th-Mar-2014___0.384 kwh
# 0                5AM  15-Aug-2014___1.201  kwh
# 1          __8PM Thu 20-Mar-2014____1.523 kwh
# 2               6PM  23rd-Apr-2014___0.424  kwh
# 3     _1AM  Friday 19th-Dec-2014___0.209  kwh
# 4         _5AM  Tue 19th-Aug-2014___1.228  kwh
# ...                                         ...
# 8754         _1AM  Fri 07th-Nov-2014_0.084 kwh
# 8755                _6AM 20-May-2014__1.027 kwh
# 8756   __2 AM  Tuesday 8th-Apr-2014___0.052 kwh
# 8757            9 PM 27th-Jan-2014_1.428  kwh
# 8758          _12 PM 25th-Aug-2014_0.528  kwh
#
# [8759 rows x 1 columns]

# %%
import sys
sys.version
# Out:
# '3.10.12 (main, Nov  6 2024, 20:22:13) [GCC 11.4.0]'

# %%
sys.platform
# Out:
# 'linux'

# %%
# Save the column name as a new row
column_name_as_row = df.columns[0]  # Extract the column name
df.loc[len(df)] = column_name_as_row  # Append it as a new row

# %%
df.columns = ["Energy Data"]

# %%
df
# Out:
#                                     Energy Data
# 0                5AM  15-Aug-2014___1.201  kwh
# 1          __8PM Thu 20-Mar-2014____1.523 kwh
# 2               6PM  23rd-Apr-2014___0.424  kwh
# 3     _1AM  Friday 19th-Dec-2014___0.209  kwh
# 4         _5AM  Tue 19th-Aug-2014___1.228  kwh
# ...                                         ...
# 8755                _6AM 20-May-2014__1.027 kwh
# 8756   __2 AM  Tuesday 8th-Apr-2014___0.052 kwh
# 8757            9 PM 27th-Jan-2014_1.428  kwh
# 8758          _12 PM 25th-Aug-2014_0.528  kwh
# 8759      3 PM  Mon 24th-Mar-2014___0.384 kwh
#
# [8760 rows x 1 columns]

# %%
df = df[df.columns[0]].astype(str).str.replace('_', ' ').str.strip()

# %%
df
# Out:
# 0                5AM  15-Aug-2014   1.201  kwh
# 1             8PM Thu 20-Mar-2014    1.523 kwh
# 2              6PM  23rd-Apr-2014   0.424  kwh
# 3       1AM  Friday 19th-Dec-2014   0.209  kwh
# 4          5AM  Tue 19th-Aug-2014   1.228  kwh
#                          ...
# 8755                6AM 20-May-2014  1.027 kwh
# 8756    2 AM  Tuesday 8th-Apr-2014   0.052 kwh
# 8757             9 PM 27th-Jan-2014 1.428  kwh
# 8758            12 PM 25th-Aug-2014 0.528  kwh
# 8759       3 PM  Mon 24th-Mar-2014   0.384 kwh
# Name: Energy Data, Length: 8760, dtype: object

# %%
import re

# Finding and separating the necessary parts of data that will be used
Time, Day, Date, Usage_kwh = [], [], [], []

# Iterate over the values in the Series directly
for i in df.values:  # Changed from df.columns[0] to df.values
    time = re.findall("^\d+\ *[A-Z]+", i)
    Time.append(time)

    day = re.findall("[A-Z]+[a-z]+\s", i)
    Day.append(day)

    date = re.findall("\d+[a-z]*\-[A-Z]+[a-z]{2}\-[0-9]{4}", i)
    Date.append(date)

    usage = re.findall("[0-9]\.\d+", i)
    Usage_kwh.append(usage)

# %%
#Gather all them within one dataframe
data_list = zip(Time, Day, Date, Usage_kwh)
column_names = ('time','day', 'date', 'usage')
electricity_df = pd.DataFrame(data_list, columns=column_names)

electricity_df
# Out:
#          time         day             date    usage
# 0       [5AM]          []    [15-Aug-2014]  [1.201]
# 1       [8PM]      [Thu ]    [20-Mar-2014]  [1.523]
# 2       [6PM]          []  [23rd-Apr-2014]  [0.424]
# 3       [1AM]   [Friday ]  [19th-Dec-2014]  [0.209]
# 4       [5AM]      [Tue ]  [19th-Aug-2014]  [1.228]
# ...       ...         ...              ...      ...
# 8755    [6AM]          []    [20-May-2014]  [1.027]
# 8756   [2 AM]  [Tuesday ]   [8th-Apr-2014]  [0.052]
# 8757   [9 PM]          []  [27th-Jan-2014]  [1.428]
# 8758  [12 PM]          []  [25th-Aug-2014]  [0.528]
# 8759   [3 PM]      [Mon ]  [24th-Mar-2014]  [0.384]
#
# [8760 rows x 4 columns]

# %%
#As the results returned as separate  lists, converting them to pandas series
time = electricity_df['time'].apply(pd.Series, index = ['time'])
day = electricity_df['day'].apply(pd.Series)
date =  electricity_df['date'].apply(pd.Series,  index = ['date'])
usage =  electricity_df['usage'].apply(pd.Series,  index = ['usage_kWh'])

# %%
#Then concatting them again to gather within one dataframe
df = pd.concat([time, day, date, usage], axis=1)
df.rename(columns={ df.columns[1]: "day" }, inplace = True)
df
# Out:
#        time       day           date usage_kWh
# 0       5AM       NaN    15-Aug-2014     1.201
# 1       8PM      Thu     20-Mar-2014     1.523
# 2       6PM       NaN  23rd-Apr-2014     0.424
# 3       1AM   Friday   19th-Dec-2014     0.209
# 4       5AM      Tue   19th-Aug-2014     1.228
# ...     ...       ...            ...       ...
# 8755    6AM       NaN    20-May-2014     1.027
# 8756   2 AM  Tuesday    8th-Apr-2014     0.052
# 8757   9 PM       NaN  27th-Jan-2014     1.428
# 8758  12 PM       NaN  25th-Aug-2014     0.528
# 8759   3 PM      Mon   24th-Mar-2014     0.384
#
# [8760 rows x 4 columns]

# %%
#There are spaces between the numbers and AM/PM in some rows, removing those spaces
df['time'] = df['time'].astype(str).str.replace(' ', '')
df
# Out:
#       time       day           date usage_kWh
# 0      5AM       NaN    15-Aug-2014     1.201
# 1      8PM      Thu     20-Mar-2014     1.523
# 2      6PM       NaN  23rd-Apr-2014     0.424
# 3      1AM   Friday   19th-Dec-2014     0.209
# 4      5AM      Tue   19th-Aug-2014     1.228
# ...    ...       ...            ...       ...
# 8755   6AM       NaN    20-May-2014     1.027
# 8756   2AM  Tuesday    8th-Apr-2014     0.052
# 8757   9PM       NaN  27th-Jan-2014     1.428
# 8758  12PM       NaN  25th-Aug-2014     0.528
# 8759   3PM      Mon   24th-Mar-2014     0.384
#
# [8760 rows x 4 columns]

# %%
#Splitting 'date' column into day, month and year
df[['Day','Months', 'Year']] = df.date.str.split("-",expand=True)
df
# Out:
#       time       day           date usage_kWh   Day Months  Year
# 0      5AM       NaN    15-Aug-2014     1.201    15    Aug  2014
# 1      8PM      Thu     20-Mar-2014     1.523    20    Mar  2014
# 2      6PM       NaN  23rd-Apr-2014     0.424  23rd    Apr  2014
# 3      1AM   Friday   19th-Dec-2014     0.209  19th    Dec  2014
# 4      5AM      Tue   19th-Aug-2014     1.228  19th    Aug  2014
# ...    ...       ...            ...       ...   ...    ...   ...
# 8755   6AM       NaN    20-May-2014     1.027    20    May  2014
# 8756   2AM  Tuesday    8th-Apr-2014     0.052   8th    Apr  2014
# 8757   9PM       NaN  27th-Jan-2014     1.428  27th    Jan  2014
# 8758  12PM       NaN  25th-Aug-2014     0.528  25th    Aug  2014
# 8759   3PM      Mon   24th-Mar-2014     0.384  24th    Mar  2014
#
# [8760 rows x 7 columns]

# %%
#Splitting 'time' column
df[['Time', 'AM/PM']] = df.time.str.split(r"[A-Z]{2}",expand=True)
df
# Out:
#       time       day           date usage_kWh   Day Months  Year Time AM/PM
# 0      5AM       NaN    15-Aug-2014     1.201    15    Aug  2014    5
# 1      8PM      Thu     20-Mar-2014     1.523    20    Mar  2014    8
# 2      6PM       NaN  23rd-Apr-2014     0.424  23rd    Apr  2014    6
# 3      1AM   Friday   19th-Dec-2014     0.209  19th    Dec  2014    1
# 4      5AM      Tue   19th-Aug-2014     1.228  19th    Aug  2014    5
# ...    ...       ...            ...       ...   ...    ...   ...  ...   ...
# 8755   6AM       NaN    20-May-2014     1.027    20    May  2014    6
# 8756   2AM  Tuesday    8th-Apr-2014     0.052   8th    Apr  2014    2
# 8757   9PM       NaN  27th-Jan-2014     1.428  27th    Jan  2014    9
# 8758  12PM       NaN  25th-Aug-2014     0.528  25th    Aug  2014   12
# 8759   3PM      Mon   24th-Mar-2014     0.384  24th    Mar  2014    3
#
# [8760 rows x 9 columns]

# %%
#Bringing AM and PM to the AM/PM column
df[[  'Time1', 'AM/PM']] = df.time.str.split(r"\d+",expand=True)
df
# Out:
#       time       day           date usage_kWh   Day Months  Year Time AM/PM  \
# 0      5AM       NaN    15-Aug-2014     1.201    15    Aug  2014    5    AM
# 1      8PM      Thu     20-Mar-2014     1.523    20    Mar  2014    8    PM
# 2      6PM       NaN  23rd-Apr-2014     0.424  23rd    Apr  2014    6    PM
# 3      1AM   Friday   19th-Dec-2014     0.209  19th    Dec  2014    1    AM
# 4      5AM      Tue   19th-Aug-2014     1.228  19th    Aug  2014    5    AM
# ...    ...       ...            ...       ...   ...    ...   ...  ...   ...
# 8755   6AM       NaN    20-May-2014     1.027    20    May  2014    6    AM
# 8756   2AM  Tuesday    8th-Apr-2014     0.052   8th    Apr  2014    2    AM
# 8757   9PM       NaN  27th-Jan-2014     1.428  27th    Jan  2014    9    PM
# 8758  12PM       NaN  25th-Aug-2014     0.528  25th    Aug  2014   12    PM
# 8759   3PM      Mon   24th-Mar-2014     0.384  24th    Mar  2014    3    PM
#
#      Time1
# 0
# 1
# 2
# 3
# 4
# ...    ...
# 8755
# 8756
# 8757
# 8758
# 8759
#
# [8760 rows x 10 columns]

# %%
#Removing unnecessary columns
df.drop(columns =["time", "date", "Time1", "day"], inplace = True)
df
# Out:
#      usage_kWh   Day Months  Year Time AM/PM
# 0        1.201    15    Aug  2014    5    AM
# 1        1.523    20    Mar  2014    8    PM
# 2        0.424  23rd    Apr  2014    6    PM
# 3        0.209  19th    Dec  2014    1    AM
# 4        1.228  19th    Aug  2014    5    AM
# ...        ...   ...    ...   ...  ...   ...
# 8755     1.027    20    May  2014    6    AM
# 8756     0.052   8th    Apr  2014    2    AM
# 8757     1.428  27th    Jan  2014    9    PM
# 8758     0.528  25th    Aug  2014   12    PM
# 8759     0.384  24th    Mar  2014    3    PM
#
# [8760 rows x 6 columns]

# %%
#Renaming columns
df.rename(columns={'Day': 'month_day', 'Months': 'months', 'Year': 'year', 'Time': 'time', 'AM/PM': 'am_pm'}, inplace=True)
df
# Out:
#      usage_kWh month_day months  year time am_pm
# 0        1.201        15    Aug  2014    5    AM
# 1        1.523        20    Mar  2014    8    PM
# 2        0.424      23rd    Apr  2014    6    PM
# 3        0.209      19th    Dec  2014    1    AM
# 4        1.228      19th    Aug  2014    5    AM
# ...        ...       ...    ...   ...  ...   ...
# 8755     1.027        20    May  2014    6    AM
# 8756     0.052       8th    Apr  2014    2    AM
# 8757     1.428      27th    Jan  2014    9    PM
# 8758     0.528      25th    Aug  2014   12    PM
# 8759     0.384      24th    Mar  2014    3    PM
#
# [8760 rows x 6 columns]

# %%
#As some of the variables in column 'month_day' contain letters, removing  them
df['month_day'] = df['month_day'].astype(str).str.replace(r'[a-z]{2}', '' , regex=True)
df
# Out:
#      usage_kWh month_day months  year time am_pm
# 0        1.201        15    Aug  2014    5    AM
# 1        1.523        20    Mar  2014    8    PM
# 2        0.424        23    Apr  2014    6    PM
# 3        0.209        19    Dec  2014    1    AM
# 4        1.228        19    Aug  2014    5    AM
# ...        ...       ...    ...   ...  ...   ...
# 8755     1.027        20    May  2014    6    AM
# 8756     0.052         8    Apr  2014    2    AM
# 8757     1.428        27    Jan  2014    9    PM
# 8758     0.528        25    Aug  2014   12    PM
# 8759     0.384        24    Mar  2014    3    PM
#
# [8760 rows x 6 columns]

# %%
#Making all numbers as double digits in 'month_day' column
df['month_day'] = df['month_day'].apply(lambda x: x.zfill(2))
df
# Out:
#      usage_kWh month_day months  year time am_pm
# 0        1.201        15    Aug  2014    5    AM
# 1        1.523        20    Mar  2014    8    PM
# 2        0.424        23    Apr  2014    6    PM
# 3        0.209        19    Dec  2014    1    AM
# 4        1.228        19    Aug  2014    5    AM
# ...        ...       ...    ...   ...  ...   ...
# 8755     1.027        20    May  2014    6    AM
# 8756     0.052        08    Apr  2014    2    AM
# 8757     1.428        27    Jan  2014    9    PM
# 8758     0.528        25    Aug  2014   12    PM
# 8759     0.384        24    Mar  2014    3    PM
#
# [8760 rows x 6 columns]

# %%
#Arranging the order of columns
df = df[['time', 'am_pm', 'month_day', 'months', 'year', 'usage_kWh']]
df
# Out:
#      time am_pm month_day months  year usage_kWh
# 0       5    AM        15    Aug  2014     1.201
# 1       8    PM        20    Mar  2014     1.523
# 2       6    PM        23    Apr  2014     0.424
# 3       1    AM        19    Dec  2014     0.209
# 4       5    AM        19    Aug  2014     1.228
# ...   ...   ...       ...    ...   ...       ...
# 8755    6    AM        20    May  2014     1.027
# 8756    2    AM        08    Apr  2014     0.052
# 8757    9    PM        27    Jan  2014     1.428
# 8758   12    PM        25    Aug  2014     0.528
# 8759    3    PM        24    Mar  2014     0.384
#
# [8760 rows x 6 columns]

# %%
#Making all numbers as double digits in 'time' column
df['time'] = df['time'].apply(lambda x: x.zfill(2))
df
# Out:
#      time am_pm month_day months  year usage_kWh
# 0      05    AM        15    Aug  2014     1.201
# 1      08    PM        20    Mar  2014     1.523
# 2      06    PM        23    Apr  2014     0.424
# 3      01    AM        19    Dec  2014     0.209
# 4      05    AM        19    Aug  2014     1.228
# ...   ...   ...       ...    ...   ...       ...
# 8755   06    AM        20    May  2014     1.027
# 8756   02    AM        08    Apr  2014     0.052
# 8757   09    PM        27    Jan  2014     1.428
# 8758   12    PM        25    Aug  2014     0.528
# 8759   03    PM        24    Mar  2014     0.384
#
# [8760 rows x 6 columns]

# %%
#Creating date column
df['date']=df['month_day'].astype(str)+'-'+df['months']+'-'+df['year']
df
# Out:
#      time am_pm month_day months  year usage_kWh         date
# 0      05    AM        15    Aug  2014     1.201  15-Aug-2014
# 1      08    PM        20    Mar  2014     1.523  20-Mar-2014
# 2      06    PM        23    Apr  2014     0.424  23-Apr-2014
# 3      01    AM        19    Dec  2014     0.209  19-Dec-2014
# 4      05    AM        19    Aug  2014     1.228  19-Aug-2014
# ...   ...   ...       ...    ...   ...       ...          ...
# 8755   06    AM        20    May  2014     1.027  20-May-2014
# 8756   02    AM        08    Apr  2014     0.052  08-Apr-2014
# 8757   09    PM        27    Jan  2014     1.428  27-Jan-2014
# 8758   12    PM        25    Aug  2014     0.528  25-Aug-2014
# 8759   03    PM        24    Mar  2014     0.384  24-Mar-2014
#
# [8760 rows x 7 columns]

# %%
#Converting 'date' column to date format then getting days of week accroding to the dates
df['date'] = pd.to_datetime(df['date'])

df['day_of_week'] = df['date'].dt.day_name()

df
# Out:
#      time am_pm month_day months  year usage_kWh       date day_of_week
# 0      05    AM        15    Aug  2014     1.201 2014-08-15      Friday
# 1      08    PM        20    Mar  2014     1.523 2014-03-20    Thursday
# 2      06    PM        23    Apr  2014     0.424 2014-04-23   Wednesday
# 3      01    AM        19    Dec  2014     0.209 2014-12-19      Friday
# 4      05    AM        19    Aug  2014     1.228 2014-08-19     Tuesday
# ...   ...   ...       ...    ...   ...       ...        ...         ...
# 8755   06    AM        20    May  2014     1.027 2014-05-20     Tuesday
# 8756   02    AM        08    Apr  2014     0.052 2014-04-08     Tuesday
# 8757   09    PM        27    Jan  2014     1.428 2014-01-27      Monday
# 8758   12    PM        25    Aug  2014     0.528 2014-08-25      Monday
# 8759   03    PM        24    Mar  2014     0.384 2014-03-24      Monday
#
# [8760 rows x 8 columns]

# %%
#Sort values according to the date and time
df.sort_values(by = ['date', 'am_pm', 'time'], inplace = True)

# %%
df
# Out:
#      time am_pm month_day months  year usage_kWh       date day_of_week
# 6315   01    AM        01    Jan  2014      0.34 2014-01-01   Wednesday
# 5067   02    AM        01    Jan  2014     0.332 2014-01-01   Wednesday
# 4105   03    AM        01    Jan  2014     0.396 2014-01-01   Wednesday
# 3238   04    AM        01    Jan  2014     0.388 2014-01-01   Wednesday
# 1814   05    AM        01    Jan  2014     2.354 2014-01-01   Wednesday
# ...   ...   ...       ...    ...   ...       ...        ...         ...
# 7958   08    PM        31    Dec  2014     1.901 2014-12-31   Wednesday
# 7702   09    PM        31    Dec  2014     0.766 2014-12-31   Wednesday
# 1859   10    PM        31    Dec  2014     0.633 2014-12-31   Wednesday
# 3864   11    PM        31    Dec  2014      0.60 2014-12-31   Wednesday
# 1472   12    PM        31    Dec  2014     0.528 2014-12-31   Wednesday
#
# [8760 rows x 8 columns]

# %%
#Creating .csv file
df.to_csv('electricity.csv', index=False)

# %%
df = pd.read_csv("electricity.csv")
df
# Out:
#       time am_pm  month_day months  year  usage_kWh        date day_of_week
# 0        1    AM          1    Jan  2014      0.340  2014-01-01   Wednesday
# 1        2    AM          1    Jan  2014      0.332  2014-01-01   Wednesday
# 2        3    AM          1    Jan  2014      0.396  2014-01-01   Wednesday
# 3        4    AM          1    Jan  2014      0.388  2014-01-01   Wednesday
# 4        5    AM          1    Jan  2014      2.354  2014-01-01   Wednesday
# ...    ...   ...        ...    ...   ...        ...         ...         ...
# 8755     8    PM         31    Dec  2014      1.901  2014-12-31   Wednesday
# 8756     9    PM         31    Dec  2014      0.766  2014-12-31   Wednesday
# 8757    10    PM         31    Dec  2014      0.633  2014-12-31   Wednesday
# 8758    11    PM         31    Dec  2014      0.600  2014-12-31   Wednesday
# 8759    12    PM         31    Dec  2014      0.528  2014-12-31   Wednesday
#
# [8760 rows x 8 columns]

# %% [markdown]
# **QUESTIONS**

# %% [markdown]
# #Question 1

# %%
#What is your average hourly electricity usage?
average_hourly_usage = round(df['usage_kWh'].mean(),3)
print(f"The average hourly electricity usage is {average_hourly_usage} kWh. \n Answer:b")
# Out:
# The average hourly electricity usage is 0.782 kWh.
#  Answer:b

# %% [markdown]
# #Question 2

# %%
#What is your average electricity usage per hour in February?
february_data = df[df['months'] == 'Feb']
average_february_usage = round(february_data['usage_kWh'].mean(),3)
print(f"The average electricity usage per hour in February is {average_february_usage} kWh. \n Answer:d")
# Out:
# The average electricity usage per hour in February is 0.833 kWh.
#  Answer:d

# %% [markdown]
# #Question 3

# %%
#Which day of the week has the highest average usage?
average_usage_by_day = df.groupby('day_of_week')['usage_kWh'].mean()
highest_average_usage_day = average_usage_by_day.idxmax()
print(f"The day of the week with the highest average usage is {highest_average_usage_day}. \n Answer:a")
# Out:
# The day of the week with the highest average usage is Sunday.
#  Answer:a

# %% [markdown]
# #Question 4

# %%
#What is the highest amount of electricity used in a continuous 4 hour period?
highest_4_hour= round(df['usage_kWh'].rolling(4).sum().max(),3)
print(f"the is the highest amount of electricity used in a continuous 4 hour period is {highest_4_hour}.\n Answer:a")
# Out:
# the is the highest amount of electricity used in a continuous 4 hour period is 17.237.
#  Answer:a

# %% [markdown]
# #Question 5

# %%
#Based on your historic electricity usage, what would your annual cost of electricity be under the "Monthly Flex" contract?
#I couldn't write contract sheet_name because I didn't have it.

# %% [markdown]
# #Question 6

# %%
#I couldn't write here because you didn't send me the cost list.
